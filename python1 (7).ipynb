# %%
print("hello py")
# Out:
# hello py

# %%
x =10.0
y =20
sum=x+y
print("sum=",sum)
print(type(sum))
# Out:
# sum= 30.0
# <class 'float'>

# %%
x=" 10"
y='python'

print(y+x)
# Out:
# python 10

# %%
x=int(input("enter the num "))
print(type(x))
# Out:
# enter the num  10
# <class 'int'>

# %%
a,b,c=10,20,30
print(c)
# Out:
# 30

# %%
x = y =z = "orange"
print(x)
print(y)
print(z)
# Out:
# orange
# orange
# orange

# %%
name = "LIKHITH"
age = 20
height = 5.99
print("name:",name)
print("age:",age)
print("height:",height)
# Out:
# name: LIKHITH
# age: 20
# height: 5.99

# %%
name=input("enter your name:")
branch=input("enter your branch:")
USN=input("enter your USN:")
year=input("enter year:")
print("name",name)
print("branch ",branch)
print("USN",USN)  
print("year",year)
# Out:
# enter your name: likhith hp
# enter your branch: AI&DS
# enter your USN: 1SV24AD026
# enter year: 2024-2025
# name likhith hp
# branch  AI&DS
# USN 1SV24AD026
# year 2024-2025

# %%
a="3.234"
print(type(a))
b= float(a)
print(type(b))
# Out:
# <class 'str'>
# <class 'float'>

# %%
a=10
print(type(a))
b= str(a)
print(type(b))
# Out:
# <class 'int'>
# <class 'str'>

# %%
#LIST+string
a=["aa","bb",10,20]
b=("aa")
print(type(a))
print(type(b))
# Out:
# <class 'list'>
# <class 'str'>

# %%
#TUPLE
b=(10,20)
print(type(b))
# Out:
# <class 'tuple'>

# %%
#dict+set
c={}
d={1}
print(type(c))
print(type(d))
# Out:
# <class 'dict'>
# <class 'set'>

# %%
name="John Doe"
print(name[0])
print(name[5])
# Out:
# J
# D

# %%
#string
first_name="John"
last_name ="Doe"
full_name =first_name +" " +last_name
print(full_name)
# Out:
# John Doe

# %%
#repetion
message = "likhith! "*5
print(message)
# Out:
# likhith! likhith! likhith! likhith! likhith!

# %%
#slicing
name="Likhith HP"
first_name = name[0:7]
last_name =name[8:]
print(first_name)
print(last_name)
# Out:
# Likhith
# HP

# %%
#lenth
name="LIKHITH HP"
print(len(name))
# Out:
# 10

# %%
sentence="  The quick brown fix jumps over the lazy dog. The dog is not so lazy after all!" 
#lowercase
print(sentence.lower())
#UPPER CASE
print(sentence.upper())
#STRIP
sentence.strip()
#REPLACE
sentence.replace("dog","cat")
sentence.title()
# Out:
#   the quick brown fix jumps over the lazy dog. the dog is not so lazy after all!
#   THE QUICK BROWN FIX JUMPS OVER THE LAZY DOG. THE DOG IS NOT SO LAZY AFTER ALL!
# '  The Quick Brown Fix Jumps Over The Lazy Dog. The Dog Is Not So Lazy After All!'

# %%
#LENTH
text="hello world"
print(len(text))
print(text[0])
print(name[10])
# Out:
# 11
# h
# d

# %%
name="hello world"
print(name[10])
# Out:
# d

# %%
text= "hello world"
print("first:",text[0])
print("last:",text[len(text)-1]
# Out:
# first: h
# last: d

# %%
d="banana"
print(d.count("a"))
# Out:
# 3

# %%
#replace
p="I LOVE PYTHON"
p.replace("PYTHON","JAVA")
# Out:
# 'I LOVE JAVA'

# %%
#reverse
text ="likhith"
print(text[::-1])
# Out:
# htihkil

# %%
a=int(input("enter the value of num1: "))
b=int(input("enter the value of num2: "))
print("a =",a)
print("b =",b)
print("sum:",a+b)
print("difference:",a-b)
print("product:",a*b)
print("division:",a/b)
print("modulus:",a%b)
# Out:
# enter the value of num1:  20
# enter the value of num2:  30
# a = 20
# b = 30
# sum: 50
# difference: -10
# product: 600
# division: 0.6666666666666666
# modulus: 20

# %%
a=int(input("enter the value of num1: "))
b=int(input("enter the value of num2: "))
print("a =",a)
print("b =",b)
print("equal:",a==b)
print("not equal:",a!=b)
print("greater than:",a>b)
print("lessthan:",a<b)
print("greater than equal:",a>=b)
print("less than equal:",a<=b)
# Out:
# enter the value of num1:  20
# enter the value of num2:  30
# a = 20
# b = 30
# equal: False
# not equal: True
# greater than: False
# lessthan: True
# greater than equal: False
# less than equal: True

# %%
a=True
b=False
print("a =",a)
print("b =",b)

print("a and b:",a and b)
print("a or b:",a or b)
print("not b:",not b)
# Out:
# a = True
# b = False
# a and b: False
# a or b: True
# not b: True

# %%
import math

r = int(input("Enter the radius of circle: "))
area = math.pi * r ** 2
print("Area of the circle:", area)
# Out:
# Enter the radius of circle:  1
# Area of the circle: 3.141592653589793
