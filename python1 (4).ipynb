# %%
class student:
    def __init__(self,name,marks):
        self.__name = name
        self.__marks = marks

    def __display_info(self):
        print("name :",self.__name)
        print("marks:",self.__marks)

    def show(self):
        print("student details:")
        self.__display_info()
s1=student("likhith hp",99)
s1.show()
# Out:
# student details:
# name : likhith hp
# marks: 99

# %%
class dog:
    def sound(self):
        return "bark"
class cat:
    def sound(self):
        return "meow"
class cow:
    def sound(self):
        return "mohi"

        
def make_sound(animal):
    print(animal.sound())
d=dog()
c=cat()
a=cow()


make_sound(d)
make_sound(c)
make_sound(a)
# Out:
# bark
# meow
# mohi

# %%
class shape:
    def area(self):
        return 0
class rectangle(shape):
    def area(self):
        length = 5
        width = 4
        return length * width
class circle(shape):
    def area(self):
        radius= 5
        return 3.14 *radius*radius

shapes  = [rectangle(),circle()]
for  s in shapes:
    print("area:",s.area())
# Out:
# area: 20
# area: 78.5

# %%
from abc import ABC,abstractmethod
class animal(ABC):
    @abstractmethod
    def sound(self):
        pass
class dog(animal):
    def sound(self):
          return "bark"
class cat(animal):
    def sound(self):
          return"meow"
         
d=dog()
c=cat()

print("dog sound:",d.sound())
print("cat sound:",c.sound())
# Out:
# dog sound: bark
# cat sound: meow

# %%
try:
    num = int(input("enter a number:"))
    print("you entred:",num)
except ValueError:
    print(" please enter only numbers!")
# Out:
# enter a number: a
#  please enter only numbers!

# %%
try:

   num1 = int(input("enter a number:"))
   num2 = int(input("enter another number:"))
   result = num1/num2
   print("result :",result)

except ValueError:
   print("please enter only integers!")

except ZeroDivisionError:
   print("you have entred zero !!")

finally:
    print("program ended!")
# Out:
# enter a number: 100
# enter another number: 2
# result : 50.0
# program ended!

# %%
try:
   num = [10,20,30,40,50]
   index = int(input("enter an index (0-4):"))
   print("value at index:",num[index])
except ValueError:
    print("enter ony number")
except IndexError:
    print("index out range!!")

finally:
    print("program endded!!")
# Out:
# enter an index (0-4): 6
# index out range!!
# program endded!!

# %%
try:
    m = int(input("Enter the marks (0–100): "))
    if m < 0 or m > 100:
        print("Please enter marks only between 0 and 100.")
    else:
        print("Marks accepted successfully!!")
except ValueError :
    print("Please enter only integers!")
finally:
    print("Program finished!")
# Out:
# Enter the marks (0–100):  100
# Marks accepted successfully!!
# Program finished!

# %%
try:
    m = int(input("Enter the marks (0–100): "))
    if m < 0 or m > 100:
        raise ValueError("marks should be between 0 and 100!")
    else:
        print("Marks accepted successfully!!")
except ValueError as e :
    print("Please enter only integers!",e)
finally:
    print("Program finished!")
# Out:
# Enter the marks (0–100):  a
# Please enter only integers! invalid literal for int() with base 10: 'a'
# Program finished!

# %%
import numpy
print(numpy.__version__)
# Out:
# 2.3.1

# %%
import numpy as np
arr = np.array([1,2,3,4,5])
print(arr)
print(type(arr))
# Out:
# [1 2 3 4 5]
# <class 'numpy.ndarray'>

# %%
def calculator():
    print("===== Simple Calculator =====")
    print("Operations:")
    print("1. Addition (+)")
    print("2. Subtraction (-)")
    print("3. Multiplication (*)")
    print("4. Division (/)")
    print("5. Modulus (%)")
    print("6. Power (**)")
    print("7. Exit")

    while True:
        try:
            choice = input("\nEnter operation (1-7): ")

            if choice == '7':
                print("Exiting calculator. Goodbye!")
                break

          
            if choice not in ('1', '2', '3', '4', '5', '6'):
                raise ValueError("Invalid operation choice! Please select a valid option (1–7).")

            num1 = float(input("Enter first number: "))
            num2 = float(input("Enter second number: "))

       
            if choice == '1':
                result = num1 + num2
                print(f"Result: {num1} + {num2} = {result}")
            elif choice == '2':
                result = num1 - num2
                print(f"Result: {num1} - {num2} = {result}")
            elif choice == '3':
                result = num1 * num2
                print(f"Result: {num1} × {num2} = {result}")
            elif choice == '4':
                # Handle division by zero
                if num2 == 0:
                    raise ZeroDivisionError("Cannot divide by zero!")
                result = num1 / num2
                print(f"Result: {num1} ÷ {num2} = {result}")
            elif choice == '5':
                result = num1 % num2
                print(f"Result: {num1} % {num2} = {result}")
            elif choice == '6':
                result = num1 ** num2
                print(f"Result: {num1}^{num2} = {result}")

        except ValueError as ve:
            print(f"Value Error: {ve}")
        except ZeroDivisionError as zde:
            print(f"Math Error: {zde}")
        except Exception as e:
            print(f"Unexpected Error: {e}")


calculator()
# Out:
# ===== Simple Calculator =====
# Operations:
# 1. Addition (+)
# 2. Subtraction (-)
# 3. Multiplication (*)
# 4. Division (/)
# 5. Modulus (%)
# 6. Power (**)
# 7. Exit
# Enter operation (1-7):  1
# Enter first number:  20
# Enter second number:  35
# Result: 20.0 + 35.0 = 55.0
# Enter operation (1-7):  2
# Enter first number:  40
# Enter second number:  5
# Result: 40.0 - 5.0 = 35.0
# Enter operation (1-7):  3
# Enter first number:  100
# Enter second number:  39
# Result: 100.0 × 39.0 = 3900.0
# Enter operation (1-7):  4
# Enter first number:  100
# Enter second number:  2
# Result: 100.0 ÷ 2.0 = 50.0
# Enter operation (1-7):  5
# Enter first number:  20
# Enter second number:  2
# Result: 20.0 % 2.0 = 0.0
# Enter operation (1-7):  6
# Enter first number:  500
# Enter second number:  5
# Result: 500.0^5.0 = 31250000000000.0
# Enter operation (1-7):  7
# Exiting calculator. Goodbye!

# %%
# Program to find ASCII value of a character

char = input("Enter a character: ")

if len(char) != 1:
    print("Please enter only a single character.")
else:
    ascii_value = ord(char)
    print(f"The ASCII value of '{char}' is {ascii_value}.")
# Out:
# Enter a character:  L
# The ASCII value of 'L' is 76.
