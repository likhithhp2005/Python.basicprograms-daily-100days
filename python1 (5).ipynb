# %%
import math
r=int(input("Enter the radius of circle:"))
area=2*math.pi*r*r
print("area of circle:",area)
# Out:
# Enter the radius of circle: 3
# area of circle: 56.548667764616276

# %%
num1=int(input("enter the number:"))
if(num1>0):
  print("positive")
else:
  print("negative")

# %%
num1=int(input("enter the number:"))
if(num1>0):
  print("positive")
elif(num1<0):
    
  print("negative")
else:
    print("zero")
# Out:
# enter the number: 0
# zero

# %%
num1=int(input("enter the number:"))
if(num1%2==0):
 print("even")
else:
 print("odd")
# Out:
# enter the number: 1
# odd

# %%
num1=int(input("enter the number:"))
if(num1==0):
 print("zero")
elif(num1%2==0):
 print("even")
else:
 print("odd")
# Out:
# enter the number: 2
# even

# %%
num=int(input("enter the number"))
print("square=",num**2)
print("cube=",num**3)
# Out:
# enter the number 9
# square= 81
# cube= 729

# %%
a=int(input("enter the marks:"))
if a>=60:
    print("first")
elif a>=45:
    print("second")
elif a>=35:
    print("pass")
else:
    print("fail")
# Out:
# enter the marks: 45
# second

# %%
for a in range(1,10):
    print("Hello---->>>",a)
# Out:
# Hello---->>> 1
# Hello---->>> 2
# Hello---->>> 3
# Hello---->>> 4
# Hello---->>> 5
# Hello---->>> 6
# Hello---->>> 7
# Hello---->>> 8
# Hello---->>> 9

# %%
fruits=["apple","orange","mango","grapes"]
for i in fruits:
    print(i)
# Out:
# apple
# orange
# mango
# grapes

# %%
stu= ["likhith","suddep","naga","lohith"]
for name in stu:
    print(name,"is abesent")
# Out:
# likhith is abesent
# suddep is abesent
# naga is abesent
# lohith is abesent

# %%
tasks = ["wake up","play","eat","sleep"]
for task in tasks:
    print("DONT'T FORGET TO:",task)
# Out:
# DONT'T FORGET TO: wake up
# DONT'T FORGET TO: play
# DONT'T FORGET TO: eat
# DONT'T FORGET TO: sleep

# %%
items=["milk","bread","rice","eggs"]
for  item in items:
    print(" cart contains items:",item)
# Out:
#  cart contains items: milk
#  cart contains items: bread
#  cart contains items: rice
#  cart contains items: eggs

# %%
#multiplication
num=int(input("enter the numbers:"))
for i in range (1,11):
    print(num,"x",i,"=",num*i)
# Out:
# enter the numbers: 3
# 3 x 1 = 3
# 3 x 2 = 6
# 3 x 3 = 9
# 3 x 4 = 12
# 3 x 5 = 15
# 3 x 6 = 18
# 3 x 7 = 21
# 3 x 8 = 24
# 3 x 9 = 27
# 3 x 10 = 30

# %%
marks=[78,85,69,90,88]
total=0
for m in marks:
    total += m
print("total marks =",total)
# Out:
# total marks = 410

# %%
n= int(input("enter the number of terms:"))
a=0
b=1
print("Fibonacci series:")

for  i in range(n):
    print(a, end=" ")
    temp = a + b
    a = b
    b = temp
# Out:
# enter the number of terms: 5
# Fibonacci series:
# 0 1 1 2 3

# %%
r= int(input("enter the num:"))
for i in range(r):
    for j in range(r):
        print("*",end=" ")
    print()
# Out:
# enter the num: 5
# * * * * *
# * * * * *
# * * * * *
# * * * * *
# * * * * *

# %%
r= int(input("enter the num:"))
for i in range(r+1):
    print(" * "*i)
# Out:
# enter the num: 4
#  *
#  *  *
#  *  *  *
#  *  *  *  *

# %%
r= int(input("enter the num:"))
for i in range(r):
    for j in range(i+1):
        print("*",end=" ")
    print()
# Out:
# enter the num: 4
# *
# * *
# * * *
# * * * *

# %%
r= int(input("enter the num:"))
for i in range(r):
    for j in range(r-i):
        print("*",end=" ")
    print()
# Out:
# enter the num: 5
# * * * * *
# * * * *
# * * *
# * *
# *

# %%
rows = 5
for i in range(rows, 0 , -1):
    print("* " * i)
# Out:
# * * * * *
# * * * *
# * * *
# * *
# *

# %%
day=int(input("enter the day"))
match day:
    case 1:
        print("monday")
    case 2:
        print("tuesday")
    case 3:
        print("wednesday")
    case 4:
        print("thursday")
    case 5:
        print("friday")
    case 6:
        print("saturday")
    case 7:
        print("sunday")
    case _:
        print("invalid day.enter the correct day.")
# Out:
# enter the day 3
# wednesday

# %%
#match 
choice = int(input("enter your choice"))
match choice:
    case 1:
        print(" you ordered pizza 🍕")
    case 2:
        print(" you ordered coffee☕")
    case 3:
        print("   you ordered ice cream🍧")
    case 4:
        print("  you ordered  car🚗")
    case _:
        print("invalid choice")
# Out:
# enter your choice 4
#   you ordered  car🚗

# %%
#append
fruits= ["apple","banana"]
fruits.append("cherry")
print(fruits)
# Out:
# ['apple', 'banana', 'cherry']

# %%
#insert
fruits= ["apple","banana"]
fruits.insert(0,"cherry")
print(fruits)
# Out:
# ['cherry', 'apple', 'banana']

# %%
#extend
fruits= ["apple","banana"]
fruits.extend(["cherry","grapes"])
print(fruits)
# Out:
# ['apple', 'banana', 'cherry', 'grapes']

# %%
#remove
fruits= ["apple","banana"]
fruits.remove("apple")
print(fruits)
# Out:
# ['banana']

# %%
#pop
fruits= ["apple","banana"]
fruits.pop(0)
print(fruits)
# Out:
# ['banana']

# %%
#clear
fruits= ["apple","banana"]
fruits.clear()
print(fruits)
# Out:
# []

# %%
#sort
nums = [3,1,4,2]
nums.sort()
print(nums)
# Out:
# [1, 2, 3, 4]

# %%
#sort
nums = ["apple","APPLE"]
nums.sort()
print(nums)
# Out:
# ['APPLE', 'apple']

# %%
#reverse
nums = [3,1,4,2]
nums.reverse()
print(nums)
# Out:
# [2, 4, 1, 3]

# %%
#index
fruits= ["apple","banana","grapes"]
print(fruits.index("banana"))
# Out:
# 1

# %%
#count
num=[1,2,11,2,3,4,5,64,4,3,3,2]
print(num.count(3))
# Out:
# 3

# %%
fruits= ["apple","banana","grapes"]
fruits.append("mango")
fruits.insert(1,"orange")
print(fruits)
# Out:
# ['apple', 'orange', 'banana', 'grapes', 'mango']

# %%
colors=["red","blue","green","yellow"]
colors.remove("green")
colors.pop()
print(colors)
# Out:
# ['red', 'blue']

# %%
items=["milk","bread","eggs"]
items.append("butter")
items.append("jam🍷")
items.remove("bread")
items.sort()
print(items)
# Out:
# ['butter', 'eggs', 'jam🍷', 'milk']

# %%
marks=(10,20,30,40)
print(len(marks))
print(min(marks))
print(max(marks))
print(sum(marks))
print(20 in marks)
print(marks[1:3])
# Out:
# 4
# 10
# 40
# 100
# True
# (20, 30)

# %%
fruits={"apple","banana","cherry"}
fruits.add("mango")
fruits.add("apple")
print(fruits)
# Out:
# {'banana', 'cherry', 'mango', 'apple'}

# %%
#sets
fruits={"apple","banana"}
fruits.add("cherry")
print(fruits)
# Out:
# {'cherry', 'banana', 'apple'}

# %%
#update
fruits={"apple","banana","cherry"}
fruits.update(["cherry","grapes"])
print(fruits)
# Out:
# {'cherry', 'banana', 'apple', 'grapes'}

# %%
fruits={"apple","banana","cherry"}
fruits.remove("banana")
print(fruits)
# Out:
# {'cherry', 'apple'}

# %%
#union
a = {1,2 ,3}
b ={3,4,5}
print(a.union(b))
# Out:
# {1, 2, 3, 4, 5}

# %%
#intersection
a = {1,2 ,3}
b ={2,3,4}
print(a.intersection(b))
# Out:
# {2, 3}

# %%
#difference
a = {1,2 ,3}
b ={2,3,4}
print(a.difference(b))
# Out:
# {1}

# %%
my={"milk","bread","eggs","butter"}
frnd={"butter","bread","jam","cheese"}
print("things we both bought:",my.intersection(my))
print(

# %%
#
